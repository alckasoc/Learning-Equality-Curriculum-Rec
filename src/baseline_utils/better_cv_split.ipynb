# %% [markdown]
# Ref: https://www.kaggle.com/code/theoviel/modeling-oriented-eda-building-a-good-cv-split

# %%
import os
import json
import numpy as np
import pandas as pd
import networkx as nx
from tqdm.notebook import tqdm

from sklearn.model_selection import StratifiedGroupKFold

# %%
from utils import read_data

# %%
DATA_PATH = "../../input/"

topics = pd.read_csv(DATA_PATH + "topics.csv")
content = pd.read_csv(DATA_PATH + "content.csv")
correlations = pd.read_csv(DATA_PATH + "correlations.csv")

# %%
train = pd.read_csv(DATA_PATH + "train.csv")

# %%
topics_val = topics[topics['category'] != "source"][["channel", "id"]]
# topics_val = topics[["channel", "id"]]

topics_val = topics_val.merge(correlations, left_on='id', right_on='topic_id')

channel_val = topics_val.groupby("channel").agg(list).reset_index()
channel_val['content_ids'] = channel_val['content_ids'].apply(lambda x: list(np.unique(np.concatenate([x_.split(' ') for x_ in x]))))

# %%
topic_channels_category = train.merge(topics, how="left", left_on="topics_ids", right_on="id")[["channel", "category"]]
train.insert(4, "channel", topic_channels_category["channel"])
train.insert(5, "category", topic_channels_category["category"])

# %%
train.insert(7, "fold", np.full(len(train), -1))

# %%
train
# Out:
#             topics_ids     content_ids  \
# 0       t_3d9ad9931021  c_efb73ad83f4b
# 1       t_3d9ad9931021  c_77574ef20c1f
# 2       t_3d9ad9931021  c_200ae87baf4d
# 3       t_3d9ad9931021  c_87e171afe50b
# 4       t_3d9ad9931021  c_3c070b63a944
# ...                ...             ...
# 615165  t_70da08637930  c_eb6448437b5f
# 615166  t_70da08637930  c_07c1da15995b
# 615167  t_70da08637930  c_17ff16d31106
# 615168  t_70da08637930  c_7cb9a57f2219
# 615169  t_70da08637930  c_9573a6ec9ae8
#
#                                                    title1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 615165  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615166  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615167  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615168  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615169  8.1.5 Use dot (.) and cross (x) diagrams to il...
#
#                                                    title2 channel  \
# 0                                                     NaN  ebc86c
# 1                                                     NaN  ebc86c
# 2                                                     NaN  ebc86c
# 3                                                     NaN  ebc86c
# 4                                                     NaN  ebc86c
# ...                                                   ...     ...
# 615165  Level 2: Describe the formation of ionic bond ...  c7ca13
# 615166  Level 3: Describe the formation of ionic bond ...  c7ca13
# 615167  Level 1: Describe the formation of ionic bond ...  c7ca13
# 615168           Ligações iônicas, covalentes e metálicas  c7ca13
# 615169              Électronégativité et liaison chimique  c7ca13
#
#             category  target  fold
# 0       supplemental       0    -1
# 1       supplemental       0    -1
# 2       supplemental       0    -1
# 3       supplemental       0    -1
# 4       supplemental       0    -1
# ...              ...     ...   ...
# 615165       aligned       0    -1
# 615166       aligned       0    -1
# 615167       aligned       0    -1
# 615168       aligned       0    -1
# 615169       aligned       0    -1
#
# [615170 rows x 8 columns]

# %%
n_folds = 5
seed = 42

train_wo_source = train[train.category!="source"].reset_index()

kfold = StratifiedGroupKFold(n_splits = n_folds, shuffle = True, random_state = seed)
for num, (_, val_index) in enumerate(kfold.split(train_wo_source, train_wo_source['target'], train_wo_source['channel'])):
    train_wo_source.loc[val_index, 'fold'] = int(num)
train_wo_source['fold'] = train_wo_source['fold'].astype(int)

# %%
train
# Out:
#             topics_ids     content_ids  \
# 0       t_3d9ad9931021  c_efb73ad83f4b
# 1       t_3d9ad9931021  c_77574ef20c1f
# 2       t_3d9ad9931021  c_200ae87baf4d
# 3       t_3d9ad9931021  c_87e171afe50b
# 4       t_3d9ad9931021  c_3c070b63a944
# ...                ...             ...
# 615165  t_70da08637930  c_eb6448437b5f
# 615166  t_70da08637930  c_07c1da15995b
# 615167  t_70da08637930  c_17ff16d31106
# 615168  t_70da08637930  c_7cb9a57f2219
# 615169  t_70da08637930  c_9573a6ec9ae8
#
#                                                    title1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 615165  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615166  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615167  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615168  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615169  8.1.5 Use dot (.) and cross (x) diagrams to il...
#
#                                                    title2 channel  \
# 0                                                     NaN  ebc86c
# 1                                                     NaN  ebc86c
# 2                                                     NaN  ebc86c
# 3                                                     NaN  ebc86c
# 4                                                     NaN  ebc86c
# ...                                                   ...     ...
# 615165  Level 2: Describe the formation of ionic bond ...  c7ca13
# 615166  Level 3: Describe the formation of ionic bond ...  c7ca13
# 615167  Level 1: Describe the formation of ionic bond ...  c7ca13
# 615168           Ligações iônicas, covalentes e metálicas  c7ca13
# 615169              Électronégativité et liaison chimique  c7ca13
#
#             category  target  fold
# 0       supplemental       0   4.0
# 1       supplemental       0   4.0
# 2       supplemental       0   4.0
# 3       supplemental       0   4.0
# 4       supplemental       0   4.0
# ...              ...     ...   ...
# 615165       aligned       0   4.0
# 615166       aligned       0   4.0
# 615167       aligned       0   4.0
# 615168       aligned       0   4.0
# 615169       aligned       0   4.0
#
# [615170 rows x 8 columns]

# %%
channel_fold_map = {}

for c in train_wo_source.channel.unique():
    channel_fold_map[c] = train_wo_source[train_wo_source.channel==c].iloc[0].fold

# %%
train["fold"] = train["channel"].map(channel_fold_map)

# %%
train.loc[train["category"] == "source", "fold"] =-1

# %%
train.fold.unique()
# Out:
# array([ 4., -1.,  2.,  3.,  0.,  1.])

# %%
train.fold.value_counts()
# Out:
# -1.0    365140
#  2.0     85180
#  3.0     46450
#  4.0     44500
#  1.0     44150
#  0.0     29750
# Name: fold, dtype: int64

# %%
train_5fold = pd.read_csv("../../input/train_5fold.csv")

# %%
train_5fold.fold.value_counts()
# Out:
# 4    123160
# 1    123130
# 2    123060
# 0    122950
# 3    122870
# Name: fold, dtype: int64

# %%
train
# Out:
#             topics_ids     content_ids  \
# 0       t_3d9ad9931021  c_efb73ad83f4b
# 1       t_3d9ad9931021  c_77574ef20c1f
# 2       t_3d9ad9931021  c_200ae87baf4d
# 3       t_3d9ad9931021  c_87e171afe50b
# 4       t_3d9ad9931021  c_3c070b63a944
# ...                ...             ...
# 615165  t_70da08637930  c_eb6448437b5f
# 615166  t_70da08637930  c_07c1da15995b
# 615167  t_70da08637930  c_17ff16d31106
# 615168  t_70da08637930  c_7cb9a57f2219
# 615169  t_70da08637930  c_9573a6ec9ae8
#
#                                                    title1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 615165  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615166  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615167  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615168  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615169  8.1.5 Use dot (.) and cross (x) diagrams to il...
#
#                                                    title2 channel  \
# 0                                                     NaN  ebc86c
# 1                                                     NaN  ebc86c
# 2                                                     NaN  ebc86c
# 3                                                     NaN  ebc86c
# 4                                                     NaN  ebc86c
# ...                                                   ...     ...
# 615165  Level 2: Describe the formation of ionic bond ...  c7ca13
# 615166  Level 3: Describe the formation of ionic bond ...  c7ca13
# 615167  Level 1: Describe the formation of ionic bond ...  c7ca13
# 615168           Ligações iônicas, covalentes e metálicas  c7ca13
# 615169              Électronégativité et liaison chimique  c7ca13
#
#             category  target  fold
# 0       supplemental       0   4.0
# 1       supplemental       0   4.0
# 2       supplemental       0   4.0
# 3       supplemental       0   4.0
# 4       supplemental       0   4.0
# ...              ...     ...   ...
# 615165       aligned       0   4.0
# 615166       aligned       0   4.0
# 615167       aligned       0   4.0
# 615168       aligned       0   4.0
# 615169       aligned       0   4.0
#
# [615170 rows x 8 columns]

# %%
train_better_cv_5fold = read_data(train)

# %%
train_better_cv_5fold
# Out:
#             topics_ids     content_ids  \
# 0       t_3d9ad9931021  c_efb73ad83f4b
# 1       t_3d9ad9931021  c_77574ef20c1f
# 2       t_3d9ad9931021  c_200ae87baf4d
# 3       t_3d9ad9931021  c_87e171afe50b
# 4       t_3d9ad9931021  c_3c070b63a944
# ...                ...             ...
# 615165  t_70da08637930  c_eb6448437b5f
# 615166  t_70da08637930  c_07c1da15995b
# 615167  t_70da08637930  c_17ff16d31106
# 615168  t_70da08637930  c_7cb9a57f2219
# 615169  t_70da08637930  c_9573a6ec9ae8
#
#                                                    title1  \
# 0                                    Title does not exist
# 1                                    Title does not exist
# 2                                    Title does not exist
# 3                                    Title does not exist
# 4                                    Title does not exist
# ...                                                   ...
# 615165  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615166  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615167  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615168  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615169  8.1.5 Use dot (.) and cross (x) diagrams to il...
#
#                                                    title2 channel  \
# 0                                    Title does not exist  ebc86c
# 1                                    Title does not exist  ebc86c
# 2                                    Title does not exist  ebc86c
# 3                                    Title does not exist  ebc86c
# 4                                    Title does not exist  ebc86c
# ...                                                   ...     ...
# 615165  Level 2: Describe the formation of ionic bond ...  c7ca13
# 615166  Level 3: Describe the formation of ionic bond ...  c7ca13
# 615167  Level 1: Describe the formation of ionic bond ...  c7ca13
# 615168           Ligações iônicas, covalentes e metálicas  c7ca13
# 615169              Électronégativité et liaison chimique  c7ca13
#
#             category  target  fold  \
# 0       supplemental       0   4.0
# 1       supplemental       0   4.0
# 2       supplemental       0   4.0
# 3       supplemental       0   4.0
# 4       supplemental       0   4.0
# ...              ...     ...   ...
# 615165       aligned       0   4.0
# 615166       aligned       0   4.0
# 615167       aligned       0   4.0
# 615168       aligned       0   4.0
# 615169       aligned       0   4.0
#
#                                                      text
# 0         Title does not exist [SEP] Title does not exist
# 1         Title does not exist [SEP] Title does not exist
# 2         Title does not exist [SEP] Title does not exist
# 3         Title does not exist [SEP] Title does not exist
# 4         Title does not exist [SEP] Title does not exist
# ...                                                   ...
# 615165  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615166  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615167  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615168  8.1.5 Use dot (.) and cross (x) diagrams to il...
# 615169  8.1.5 Use dot (.) and cross (x) diagrams to il...
#
# [615170 rows x 9 columns]

# %%
train_better_cv_5fold.to_csv("../../input/train_better_cv_5fold.csv", index=False)
